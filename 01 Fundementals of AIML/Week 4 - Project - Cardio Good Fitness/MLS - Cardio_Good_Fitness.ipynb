# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Note:-This-is-a-sample-solution-for-the-project.-Projects-will-NOT-be-graded-on-the-basis-of-how-well-the-submission-matches-this-sample-solution.-Projects-will-be-graded-on-the-basis-of-the-rubric-only." data-toc-modified-id="Note:-This-is-a-sample-solution-for-the-project.-Projects-will-NOT-be-graded-on-the-basis-of-how-well-the-submission-matches-this-sample-solution.-Projects-will-be-graded-on-the-basis-of-the-rubric-only.-0.1">Note: This is a sample solution for the project. Projects will NOT be graded on the basis of how well the submission matches this sample solution. Projects will be graded on the basis of the rubric only.</a></span></li></ul></li><li><span><a href="#Objective:" data-toc-modified-id="Objective:-1">Objective:</a></span></li><li><span><a href="#Data:" data-toc-modified-id="Data:-2">Data:</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-the-necessary-packages" data-toc-modified-id="Import-the-necessary-packages-2.0.1">Import the necessary packages</a></span></li><li><span><a href="#Read-the-dataset" data-toc-modified-id="Read-the-dataset-2.0.2">Read the dataset</a></span></li><li><span><a href="#View-the-first-and-last-5-rows-of-the-dataset." data-toc-modified-id="View-the-first-and-last-5-rows-of-the-dataset.-2.0.3">View the first and last 5 rows of the dataset.</a></span></li><li><span><a href="#Understand-the-shape-of-the-dataset." data-toc-modified-id="Understand-the-shape-of-the-dataset.-2.0.4">Understand the shape of the dataset.</a></span></li><li><span><a href="#Check-the-data-types-of-the-columns-for-the-dataset." data-toc-modified-id="Check-the-data-types-of-the-columns-for-the-dataset.-2.0.5">Check the data types of the columns for the dataset.</a></span></li></ul></li><li><span><a href="#Fixing-the-data-types" data-toc-modified-id="Fixing-the-data-types-2.1">Fixing the data types</a></span><ul class="toc-item"><li><span><a href="#Give-a-statistical-summary-for-the-dataset." data-toc-modified-id="Give-a-statistical-summary-for-the-dataset.-2.1.1">Give a statistical summary for the dataset.</a></span></li><li><span><a href="#Check-for-missing-values" data-toc-modified-id="Check-for-missing-values-2.1.2">Check for missing values</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2.1.3">EDA</a></span></li><li><span><a href="#Univariate-analysis" data-toc-modified-id="Univariate-analysis-2.1.4">Univariate analysis</a></span></li></ul></li><li><span><a href="#Observations-on-Age" data-toc-modified-id="Observations-on-Age-2.2">Observations on Age</a></span></li><li><span><a href="#Observations-on-Education" data-toc-modified-id="Observations-on-Education-2.3">Observations on Education</a></span></li><li><span><a href="#Observations-on-Usage" data-toc-modified-id="Observations-on-Usage-2.4">Observations on Usage</a></span></li><li><span><a href="#Observations-on-Income" data-toc-modified-id="Observations-on-Income-2.5">Observations on Income</a></span></li><li><span><a href="#Observations-on-Miles" data-toc-modified-id="Observations-on-Miles-2.6">Observations on Miles</a></span></li><li><span><a href="#Observations-on-Product" data-toc-modified-id="Observations-on-Product-2.7">Observations on Product</a></span></li><li><span><a href="#Observations-on-Gender" data-toc-modified-id="Observations-on-Gender-2.8">Observations on Gender</a></span></li><li><span><a href="#Observations-on-Marital-Status" data-toc-modified-id="Observations-on-Marital-Status-2.9">Observations on Marital Status</a></span></li><li><span><a href="#Observations-on-Fitness" data-toc-modified-id="Observations-on-Fitness-2.10">Observations on Fitness</a></span></li><li><span><a href="#Observations-on-Education" data-toc-modified-id="Observations-on-Education-2.11">Observations on Education</a></span></li><li><span><a href="#Observations-on-Usage" data-toc-modified-id="Observations-on-Usage-2.12">Observations on Usage</a></span></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-2.13">Bivariate Analysis</a></span><ul class="toc-item"><li><span><a href="#Product-vs-Age" data-toc-modified-id="Product-vs-Age-2.13.1">Product vs Age</a></span></li></ul></li><li><span><a href="#Product-vs-Education" data-toc-modified-id="Product-vs-Education-2.14">Product vs Education</a></span></li><li><span><a href="#Product-vs-Usage" data-toc-modified-id="Product-vs-Usage-2.15">Product vs Usage</a></span></li><li><span><a href="#Product-vs-Income" data-toc-modified-id="Product-vs-Income-2.16">Product vs Income</a></span></li><li><span><a href="#Product-vs-Miles" data-toc-modified-id="Product-vs-Miles-2.17">Product vs Miles</a></span></li><li><span><a href="#Product-vs-Gender" data-toc-modified-id="Product-vs-Gender-2.18">Product vs Gender</a></span></li><li><span><a href="#Product-vs-Marital-Status" data-toc-modified-id="Product-vs-Marital-Status-2.19">Product vs Marital Status</a></span></li><li><span><a href="#Product-vs-Fitness" data-toc-modified-id="Product-vs-Fitness-2.20">Product vs Fitness</a></span><ul class="toc-item"><li><span><a href="#Grouping-data-w.r.t-to-products-to-build-customer-profiles" data-toc-modified-id="Grouping-data-w.r.t-to-products-to-build-customer-profiles-2.20.1">Grouping data w.r.t to products to build customer profiles</a></span><ul class="toc-item"><li><span><a href="#TM195-Customer" data-toc-modified-id="TM195-Customer-2.20.1.1">TM195 Customer</a></span></li><li><span><a href="#TM498-Customer" data-toc-modified-id="TM498-Customer-2.20.1.2">TM498 Customer</a></span></li><li><span><a href="#TM798-Customer" data-toc-modified-id="TM798-Customer-2.20.1.3">TM798 Customer</a></span></li></ul></li><li><span><a href="#Customer-Segmentation" data-toc-modified-id="Customer-Segmentation-2.20.2">Customer Segmentation</a></span></li></ul></li><li><span><a href="#Usage-vs-Gender-vs-Marital-Status" data-toc-modified-id="Usage-vs-Gender-vs-Marital-Status-2.21">Usage vs Gender vs Marital Status</a></span></li><li><span><a href="#Gender-vs-Income" data-toc-modified-id="Gender-vs-Income-2.22">Gender vs Income</a></span></li><li><span><a href="#Gender-vs-Income-vs-Marital-Status" data-toc-modified-id="Gender-vs-Income-vs-Marital-Status-2.23">Gender vs Income vs Marital Status</a></span></li><li><span><a href="#Gender-vs-Miles" data-toc-modified-id="Gender-vs-Miles-2.24">Gender vs Miles</a></span></li><li><span><a href="#Gender-vs-Miles-vs-Marital-Status" data-toc-modified-id="Gender-vs-Miles-vs-Marital-Status-2.25">Gender vs Miles vs Marital Status</a></span></li><li><span><a href="#Gender-vs-Miles-vs-Education" data-toc-modified-id="Gender-vs-Miles-vs-Education-2.26">Gender vs Miles vs Education</a></span></li><li><span><a href="#Age-vs-Miles-vs-Gender" data-toc-modified-id="Age-vs-Miles-vs-Gender-2.27">Age vs Miles vs Gender</a></span></li><li><span><a href="#Age-vs-Miles-vs-Marital-Status" data-toc-modified-id="Age-vs-Miles-vs-Marital-Status-2.28">Age vs Miles vs Marital Status</a></span></li><li><span><a href="#Age-vs-Income-vs-Product" data-toc-modified-id="Age-vs-Income-vs-Product-2.29">Age vs Income vs Product</a></span></li><li><span><a href="#Income-vs-Miles-vs-Education" data-toc-modified-id="Income-vs-Miles-vs-Education-2.30">Income vs Miles vs Education</a></span></li><li><span><a href="#Income-vs-Miles-vs-Product" data-toc-modified-id="Income-vs-Miles-vs-Product-2.31">Income vs Miles vs Product</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-2.32">Conclusion</a></span><ul class="toc-item"><li><span><a href="#Key-insights" data-toc-modified-id="Key-insights-2.32.1">Key insights</a></span><ul class="toc-item"><li><span><a href="#TM195:" data-toc-modified-id="TM195:-2.32.1.1">TM195:</a></span></li><li><span><a href="#TM495:" data-toc-modified-id="TM495:-2.32.1.2">TM495:</a></span></li><li><span><a href="#TM798:" data-toc-modified-id="TM798:-2.32.1.3">TM798:</a></span></li></ul></li><li><span><a href="#Business-Recommendations" data-toc-modified-id="Business-Recommendations-2.32.2">Business Recommendations</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ## Note: This is a sample solution for the project. Projects will NOT be graded on the basis of how well the submission matches this sample solution. Projects will be graded on the basis of the rubric only.

# %% [markdown]
# # Objective:
#
# * Explore the dataset and extract actionable insights that will enable growth in the market.
# * Perform univariate and multivariate analysis.
# * Building customer profiles (characteristics of a customer) for the different products.
# * Generate set of recommendations that will help the company in targeting new customers.
#
#
# # Data:
# **CardioGoodFitness.csv** - It contains information about customer's purchasing product.
#
# * Product - The model no. of the treadmill
# * Gender - Gender of the customer
# * Education - Education of the customer in no. of years
# * Marital Status - Marital status of the customer
# * Usage - Avg. # times the customer wants to use the treadmill every week
# * Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit)
# * Income - Income of the customer
# * Miles- Miles that a customer expects to run

# %% [markdown]
# ### Import the necessary packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **What is subject of the dataset?**
# - Each row is a customer. The primary subject is customer
# - There is a secondary subject of the dataset which is the product.
# - All analysis will be about the customers and products
#
# **We want to**
# - Enable growth
# - Build customer profiles
# - Recommendations for targeting new customers
#
# **For a given product:**
# - Univariate distributions
#     - Simple Questions
#     - What is the average and spread of age,income, miles for this product
#     - What is the count of all other cat variables (Gender, Marital Status, Usage etc)
#     - Build a customer profile, (a story)
#         - For product X, customers have an average age of 23 but range from 16-42. Their income also has a wide range
# - Multivariate analysis center the discussion around age and gender. Easy and understandable
#     - Dive Deeper
#     - Explore Age vs Gender vs other variables
#     - E.g. Age vs Gender vs Income. How does income vary by age and gender?
#     - E.g. Age vs Gender vs Miles. How does the perception of "how much running" change by age and gender?
#
# - Bin additional columns
#
#
# **Across different products**
# - Develop context for the individual product analysis.
# - Showcase the story about this is what we saw in Age vs Gender vs Income for all 3 products.
# - The objective now is to capture what is the overlap and what is unique between the customer profile characteristics for each product
# - Customer profile characteristics that are unique can be targeted in marketing wtih only those specific product
#
# **Conclusions**
#
# **Possible path forward (unanswered questions)**
# - If we had customer ids, we could see if the same customer purchases multiple products
# - Furthermore,with the dates, we could recommend when in a customer's lifecycle do they upgrade

# %% [markdown]
# ### Read the dataset

# %%
data=pd.read_csv("CardioGoodFitness.csv")

# %%
# copying data to another varaible to avoid any changes to original data
cardio=data.copy()

# %% [markdown]
# ### View the first and last 5 rows of the dataset.

# %%
cardio.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
cardio.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# ### Understand the shape of the dataset.

# %%
cardio.shape
# Out:
# (180, 9)

# %% [markdown]
# * Dataset has 180 rows and 9 columns.

# %% [markdown]
# ### Check the data types of the columns for the dataset.

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# ## Fixing the data types
# * All variables are Integer are valid data type except for fitness, it is a rating given by a customer for self-fitness on a scale of 5, it should be treated as a category.
#
#
# * Product,Gender and Marital Status are of object type, we can change them to categories.
#
# `coverting "objects" to "category" reduces the data space required to store the dataframe`

# %%
cardio["Product"]=cardio["Product"].astype("category")
cardio["Gender"]=cardio["Gender"].astype("category")
cardio["MaritalStatus"]=cardio["MaritalStatus"].astype("category")
cardio["Fitness"]=cardio["Fitness"].astype("category")

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    category
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    category
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    category
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    category
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: category(4), int64(5)
# memory usage: 8.3 KB

# %% [markdown]
# * Product,Gender, Marital Status and Fitness have been converted to categories
#
# `we can see that the memory usage has decreased from 12.8KB to 8.3KB`

# %% [markdown]
# ### Give a statistical summary for the dataset.

# %%
cardio.describe()
# Out:
#               Age   Education       Usage         Income       Miles
# count  180.000000  180.000000  180.000000     180.000000  180.000000
# mean    28.788889   15.572222    3.455556   53719.577778  103.194444
# std      6.943498    1.617055    1.084797   16506.684226   51.863605
# min     18.000000   12.000000    2.000000   29562.000000   21.000000
# 25%     24.000000   14.000000    3.000000   44058.750000   66.000000
# 50%     26.000000   16.000000    3.000000   50596.500000   94.000000
# 75%     33.000000   16.000000    4.000000   58668.000000  114.750000
# max     50.000000   21.000000    7.000000  104581.000000  360.000000

# %% [markdown]
# * Mean of Age is greater than the median, this suggests that Age is right skewed.
# * Education,Usage,Fitness has approximately same mean and median.
# * Mean is greater than the median for Income and Miles variable which suggests that these variables are right skewed.

# %%
cardio.describe(include=["category"])
# Out:
#        Product Gender MaritalStatus  Fitness
# count      180    180           180      180
# unique       3      2             2        5
# top      TM195   Male     Partnered        3
# freq        80    104           107       97

# %% [markdown]
# * Product has three types of treadmill models, TM195 being the most sold model.
# * Males(104) have purchased most products as compared to females(76).
# * Married customers(107) have purchased most products as compared to singles(73)
# * Most customers(97) rate them as 3 on a scale of 1 to 5 in Fitness levels.

# %% [markdown]
# ### Check for missing values

# %%
cardio.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# * There are no missing values in the data.

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Univariate analysis

# %%
# While doing uni-variate analysis of numerical variables we want to study their central tendency 
# and dispersion.
# Let us write a function that will help us create boxplot and histogram for any input numerical 
# variable.
# This function takes the numerical column as the input and returns the boxplots 
# and histograms for the variable.
# Let us see if this help us write faster and cleaner code.
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,ncols =2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ## Observations on Age

# %%
histogram_boxplot(cardio, "Age")

# %% [markdown]
# * The distribution of Age is right skewed.
# * There are a outliers in this variable.
# * From boxplot we can see that the third quartile(Q3) is equal to 33 which means 75% of customers are below the age of 33.

# %% [markdown]
# ## Observations on Education

# %%
histogram_boxplot(cardio, "Education")

# %% [markdown]
# * Mean education for customers is 15.5 years
# * There are a few outliers present in data (customers who have education of more than 18 years)

# %% [markdown]
# ## Observations on Usage

# %%
histogram_boxplot(cardio, "Usage")

# %% [markdown]
# * Customers want to use the treadmills 3-4 times a week on an average.
# * There are few outliers, customers who wish to use treadmills 6-7 times a week.

# %% [markdown]
# ## Observations on Income

# %%
histogram_boxplot(cardio, "Income")

# %% [markdown]
# * Mean income of customers who bought treadmill is around 55000.
# * Income is right skewed.
# * It has many ouliers towards the higher end.

# %% [markdown]
# ## Observations on Miles

# %%
histogram_boxplot(cardio, "Miles")

# %% [markdown]
# * Most customers expect to run 100 miles per week.
# * Miles run is right skewed
# * There are outliers present, some customers expect to run more than 200 miles per week, some customers wish to run more than 350 miles per week this could be an error in data collection or any professional runner bought the product.

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# ## Observations on Product

# %%
labeled_barplot(cardio, "Product", perc=True)

# %% [markdown]
# * Highest selling product is TM195(44.4%),followed by TM498(33.3%) and TM798(22.2%)

# %% [markdown]
# ## Observations on Gender

# %%
labeled_barplot(cardio, "Gender", perc=True)

# %% [markdown]
# * There are more males customers(57.8%) than females(42.2%)

# %% [markdown]
# ## Observations on Marital Status

# %%
labeled_barplot(cardio, "MaritalStatus", perc=True)

# %% [markdown]
# * 40.6% of customers are single while 59.4% of customers have a partner.

# %% [markdown]
# ## Observations on Fitness

# %%
labeled_barplot(cardio, "Fitness", perc=True)

# %% [markdown]
# * 53.9% of the customers have rated them at 3 on a scale of 5 (1 being the least fit and 5 being the most fit),followed by 5 rating (17.2%).

# %% [markdown]
# ## Observations on Education
#
# * We saw earlier that years of education has a mean of 15.5 years of education, let's check what is the proportion of each level of education among our customer population.

# %%
labeled_barplot(cardio, "Education", perc=True)

# %% [markdown]
# * 47.2% of customers have 16 years of education, followed by 14 years of education(30.6%).

# %% [markdown]
# ## Observations on Usage
#
# * We saw earlier that customers wish to use products for 3-4 days in a week, let's check what is the proportion of each level of usage among our customer population.

# %%
labeled_barplot(cardio, "Usage", perc=True)

# %% [markdown]
# * 38.3% of customers wish to use the product 3 times a week followed by 28.9% customers who wish to use the product 4 times a week.

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(cardio.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="viridis_r")
plt.show()

# %% [markdown]
# * Miles is highly correlated with usage, a customer running more miles would mean he is also using the treadmill more.
# * Education and Income has a positive correlation, indicating higher the education higher would be the income.
# * Income shows a positive correlation with Age , Usage, and Miles.
# * A positive correlation between age and income is expected but a high poistive correlation of income with usage and miles should be investigated further.

# %%
sns.pairplot(data=cardio,hue="Product", diag_kind="kde")
plt.show()

# %% [markdown]
# * We can see varying distributions in variables for different products, we should investigate it further.

# %% [markdown]
# ### Product vs Age

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Product"],cardio["Age"],palette="PuBu")
plt.show()

# %% [markdown]
# * TM195 and TM498 are preferred by customers of all ages but for TM798 customers are in the range of above 22 and below 38 (but there are some outliers)

# %% [markdown]
# ## Product vs Education

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Product"],cardio["Education"],palette="PuBu")
plt.show()

# %% [markdown]
# * Customers buying TM798 have higher education as compared to the customers buying the other two other products

# %% [markdown]
# ## Product vs Usage

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Product"],cardio["Usage"],palette="PuBu")
plt.show()

# %% [markdown]
# * Customers who have higher expected treadmill usage(greater than 3 days) prefer the TM798 product, Customers with very light(2-3 days) usage prefer TM498, customers who have moderate usage (greater than 2 days but less than or equal to 5 days) prefer TM195.

# %% [markdown]
# ## Product vs Income

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Product"],cardio["Income"],palette="PuBu")
plt.show()

# %% [markdown]
# * Customers with higher income prefer TM798, whereas TM195 and TM498 are prefered by middle income customers.

# %% [markdown]
# ## Product vs Miles

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Product"],cardio["Miles"],palette="PuBu")
plt.show()

# %% [markdown]
# * Customers who expect to run higher miles go for TM798.

# %% [markdown]
# ## Product vs Gender

# %%
plt.figure(figsize=(15,7))
sns.countplot(cardio["Product"],hue=cardio["Gender"],palette='winter')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * TM798 has been bought more by the male customers as compared to the female customers, for TM195 and TM498 there is equal distribution among genders

# %% [markdown]
# ## Product vs Marital Status

# %%
plt.figure(figsize=(15,7))
sns.countplot(cardio["Product"],hue=cardio["MaritalStatus"],palette='winter')
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * All the products are couple/partner friendly.
# * Couples/partnered customers have a higher chance of buying a product when compared to single customers.

# %% [markdown]
# ## Product vs Fitness

# %%
plt.figure(figsize=(15,7))
sns.countplot(cardio["Product"],hue=cardio["Fitness"],palette="gnuplot2_r")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * Customers who purchased  TM195 and TM498 gave themselves a balanced fitness rating of 3  (on a scale of 5, 1 being the least fit and 5 being the most fit), but for TM798 most of customers have rated themselves higher in fitness that is 5.

# %% [markdown]
# ### Grouping data w.r.t to products to build customer profiles

# %%
cardio[cardio["Product"]=="TM195"].describe(include="all")
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  Fitness  \
# count       80  80.000000     80  80.000000            80  80.000000     80.0
# unique       1        NaN      2        NaN             2        NaN      5.0
# top      TM195        NaN   Male        NaN     Partnered        NaN      3.0
# freq        80        NaN     40        NaN            48        NaN     54.0
# mean       NaN  28.550000    NaN  15.037500           NaN   3.087500      NaN
# std        NaN   7.221452    NaN   1.216383           NaN   0.782624      NaN
# min        NaN  18.000000    NaN  12.000000           NaN   2.000000      NaN
# 25%        NaN  23.000000    NaN  14.000000           NaN   3.000000      NaN
# 50%        NaN  26.000000    NaN  16.000000           NaN   3.000000      NaN
# 75%        NaN  33.000000    NaN  16.000000           NaN   4.000000      NaN
# max        NaN  50.000000    NaN  18.000000           NaN   5.000000      NaN
#
#              Income       Miles
# count      80.00000   80.000000
# unique          NaN         NaN
# top             NaN         NaN
# freq            NaN         NaN
# mean    46418.02500   82.787500
# std      9075.78319   28.874102
# min     29562.00000   38.000000
# 25%     38658.00000   66.000000
# 50%     46617.00000   85.000000
# 75%     53439.00000   94.000000
# max     68220.00000  188.000000

# %% [markdown]
# #### TM195 Customer
#
# The TM195 customer is our regular customer (since this product is sold more than others).
# * Early 20’s to early 30’s
# * 12-18 years of educataion
# * Income between 40K and 50K
# * Plans to use treadmill three to four times per week for light usage.
# * Has an average fitness level (rated 3)

# %%
cardio[cardio["Product"]=="TM498"].describe(include="all")
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  Fitness  \
# count       60  60.000000     60  60.000000            60  60.000000     60.0
# unique       1        NaN      2        NaN             2        NaN      4.0
# top      TM498        NaN   Male        NaN     Partnered        NaN      3.0
# freq        60        NaN     31        NaN            36        NaN     39.0
# mean       NaN  28.900000    NaN  15.116667           NaN   3.066667      NaN
# std        NaN   6.645248    NaN   1.222552           NaN   0.799717      NaN
# min        NaN  19.000000    NaN  12.000000           NaN   2.000000      NaN
# 25%        NaN  24.000000    NaN  14.000000           NaN   3.000000      NaN
# 50%        NaN  26.000000    NaN  16.000000           NaN   3.000000      NaN
# 75%        NaN  33.250000    NaN  16.000000           NaN   3.250000      NaN
# max        NaN  48.000000    NaN  18.000000           NaN   5.000000      NaN
#
#               Income       Miles
# count      60.000000   60.000000
# unique           NaN         NaN
# top              NaN         NaN
# freq             NaN         NaN
# mean    48973.650000   87.933333
# std      8653.989388   33.263135
# min     31836.000000   21.000000
# 25%     44911.500000   64.000000
# 50%     49459.500000   85.000000
# 75%     53439.000000  106.000000
# max     67083.000000  212.000000

# %% [markdown]
# #### TM498 Customer
#
# The TM498 customers is similar to the TM195 customer in most aspects. The differences are that these customers have a slightly higher annual income, a narrower usage, and a broader expectation of Miles to run each week.
#
# With such a specific usage anticipation it is likely the TM498 customer is a working adult with a fixed or busy schedule (since these customers only tend to use the treadmill 3 times a week)
#
# * Adult in their mid 20’s to early 30’s
# * 12-18 years of educatation.
# * Income around 50K.
# * Plans to use treadmill three days a week for a light to moderate amount.
# * Has an average fitness level.

# %%
cardio[cardio["Product"]=="TM798"].describe(include="all")
# Out:
#        Product        Age Gender  Education MaritalStatus      Usage  Fitness  \
# count       40  40.000000     40  40.000000            40  40.000000     40.0
# unique       1        NaN      2        NaN             2        NaN      3.0
# top      TM798        NaN   Male        NaN     Partnered        NaN      5.0
# freq        40        NaN     33        NaN            23        NaN     29.0
# mean       NaN  29.100000    NaN  17.325000           NaN   4.775000      NaN
# std        NaN   6.971738    NaN   1.639066           NaN   0.946993      NaN
# min        NaN  22.000000    NaN  14.000000           NaN   3.000000      NaN
# 25%        NaN  24.750000    NaN  16.000000           NaN   4.000000      NaN
# 50%        NaN  27.000000    NaN  18.000000           NaN   5.000000      NaN
# 75%        NaN  30.250000    NaN  18.000000           NaN   5.000000      NaN
# max        NaN  48.000000    NaN  21.000000           NaN   7.000000      NaN
#
#               Income       Miles
# count       40.00000   40.000000
# unique           NaN         NaN
# top              NaN         NaN
# freq             NaN         NaN
# mean     75441.57500  166.900000
# std      18505.83672   60.066544
# min      48556.00000   80.000000
# 25%      58204.75000  120.000000
# 50%      76568.50000  160.000000
# 75%      90886.00000  200.000000
# max     104581.00000  360.000000

# %% [markdown]
# #### TM798 Customer
#
# The TM798 model attracts a specific customer. In stark contrast to models T498 and T195, the T798 customer is predominantly male, highly educated and has higher salary.
# * Generally preferred by Males in late 20’s
# * Highly Educated
# * Higher income earner
# * Plans to use treadmill 4-5 days a week, running 160 miles on an average.
# * Considers themselves very fit.

# %% [markdown]
# ### Customer Segmentation
#
# This will help us to understand and cater needs of customers better based on their gender,marital status, Age etc.

# %% [markdown]
# ## Usage vs Gender vs Marital Status

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Gender"],cardio["Usage"],hue=cardio["MaritalStatus"],palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * Usage for single females, single or partnered male is same it varies for females that have a partner.

# %% [markdown]
# ## Gender vs Income

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Gender"],cardio["Income"],palette="viridis")
plt.show()

# %% [markdown]
# * There is a large disparity in income of both the genders, there are more males with higher income than females.

# %% [markdown]
# ## Gender vs Income vs Marital Status

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Gender"],cardio["Income"],hue=cardio["MaritalStatus"],palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * Males with a partner have higher income, while the income for single and partnered females is almost compareable.

# %% [markdown]
# ## Gender vs Miles

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Gender"],cardio["Miles"],palette="viridis")
plt.show()

# %% [markdown]
# * Males expect to run more miles than females

# %% [markdown]
# ## Gender vs Miles vs Marital Status

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Gender"],cardio["Miles"],hue=cardio["MaritalStatus"],palette="viridis")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * Single and Partnered male expect to run more miles, while not much difference can be noticed between Single or Partnered females.

# %% [markdown]
# ## Gender vs Miles vs Education

# %%
plt.figure(figsize=(15,7))
sns.boxplot(cardio["Gender"],cardio["Miles"],hue=cardio["Education"])
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * The expected miles to run increases as the education level increases, indicating that the more educated customers are more fitness aware.

# %% [markdown]
# ## Age vs Miles vs Gender

# %%
plt.figure(figsize=(15,7))
sns.lineplot(cardio["Age"],cardio["Miles"],hue=cardio["Gender"],ci="sd")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * With the increase in age the average expected miles to run decreases in females, whereas for males it shows an increasing and decreasing trend.
# * As the age increases above 25, males expect to run more miles than females.
# * After 30 there is a sharp decrease in the Average miles a female expects to run.

# %% [markdown]
# ## Age vs Miles vs Marital Status

# %%
plt.figure(figsize=(15,7))
sns.lineplot(cardio["Age"],cardio["Miles"],hue=cardio["MaritalStatus"],ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * The trend is mostly similar across younger years for a single or a customer with a partner, however after 40 years singles tend to work more on their fitness.

# %% [markdown]
# ## Age vs Income vs Product

# %%
plt.figure(figsize=(15,7))
sns.lineplot(cardio["Age"],cardio["Income"],hue=cardio["Product"],ci=0)
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * TM195 and TM498 have simlilar income group customers[30k-60k] for all age groups but TM798 is purchased by higher income [greater than 60k] customers only for all age groups.

# %% [markdown]
# ## Income vs Miles vs Education

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(cardio["Income"],cardio["Miles"],hue=cardio["Education"],ci=0.,palette="Dark2")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# *  Customers having an income of more than 70k have 18-21 years of education and expect to run 100-200 miles a week.

# %% [markdown]
# ## Income vs Miles vs Product

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(cardio["Income"],cardio["Miles"],hue=cardio["Product"],ci=0,palette="inferno")
plt.legend(bbox_to_anchor=(1.00, 1))
plt.show()

# %% [markdown]
# * Customers having an income of more than 70k tend to buy TM798 and run more miles.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Key insights
#
# #### TM195:
#
# * An affordable and general-purpose treadmill that can be used for a wide range of users.
#
# * It can be considered as an entry-level product generally targeted for first-time fitness enthusiasts or college-going population.
#
# * Customers with light to moderate usage 3 to 4 times a week go for this product.
#
#
# #### TM495:
#
# * An affordable product like the TM195 with more features and probably has a high price than TM195.
#
# * The product also generally targets the same age group as the TM195 but has users of slightly higher income.
#
# * The product is used generally 3 times per week.
#
#
# #### TM798:
#
# * A top of the range treadmill with plenty of features that excite the fitness enthusiasts.
#
# * It has a higher price point and probably the flagship product of the company.
#
# * The buyers of the product are core users that rate themselves very highly on the fitness score as evident from the usage and expected miles to run.
#
# * The buyers in this segment are more educated, have an income(greater than 60k) more than the other two treadmill users, and take their fitness very seriously.
#
# * Male customers prefer this product more than females.

# %% [markdown]
# ### Business Recommendations

# %% [markdown]
# * The company has an affordable product in its portfolio that brings in the bulk of the volume of its sales, which is the TM195. The TM798 is their flagship product that brings in the profits for the company.
#
#
# * The company needs to engage in more marketing to convey that product TM798 is suitable for both the genders and try to lure the younger age group into buying their flagship product. Currently, it seems TM798 is marketed as an exclusive product for the males making more money as there is a large disparity in income for both genders.
#
#
# * Years of education are proportionate to income, and so customers with higher education can be recommended an expensive model(TM798).
#
#
# * Females above 30 years can be recommended the lower end products(TM195 and TM498) since they wish to run a fewer number of miles and therefore the usage of the product won't be higher.
#
#
# * Partnered Females can be recommended all types of products (low end to high end) since their usage varies from 2 days per week to 6 days per week.
#
#
# * Singles above 40 years can be recommended the higher end product(TM798) since they wish to run more miles and therefore the usage would be higher.
#
#
# * Partnered males have a higher income and also expect to run more miles hence the higher end product TM798 would be a good recommendation for them.
