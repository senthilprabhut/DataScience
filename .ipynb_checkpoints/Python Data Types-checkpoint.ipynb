# %% [markdown]
# # Introduction
#
# You can visualize the python execution at http://pythontutor.com/visualize.html#mode=edit

# %%
2*3
# Out:
# 6

# %%
print('Hello World 6')
# Out:
# Hello World 6

# %% [markdown]
# # Data Types
# * Integer
# * Float
# * String
# * Boolean

# %%
type(True)
# Out:
# bool

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
type('Hello World')
# Out:
# str

# %%
type('$')
# Out:
# str

# %%
# Variables in python
a=3
print('Five times a is ', 5*a, 'and 3 multiplied by a is ', 3*a)
# Out:
# Five times a is  15 and 3 multiplied by a is  9

# %%
# Inspect the variable types
print('a is of type ', type(a))
b = 2.1
print('b is of type ', type(b))
c = float(a)/b
print('c is of type ', type(c), 'and its value is ', c)
d = a/b
print('d is of type ', type(d), 'and its value is ', d)
a = 24
e = a/7
print('e is of type ', type(e), 'and its value is ', e)
# Out:
# a is of type  <class 'int'>
# b is of type  <class 'float'>
# c is of type  <class 'float'> and its value is  11.428571428571429
# d is of type  <class 'float'> and its value is  11.428571428571429
# e is of type  <class 'float'> and its value is  3.4285714285714284

# %% [markdown]
# # Collections of variables
# There are 4 main types of variables in python
# 1. list
# 2. touple
# 3. set
# 4. dictionary

# %%
# a list is an ordered and indexed collection of values that are changeable and allows duplicates
simple_list = ['Dan', 2, 3, 4, 'python', 3.8]
print(simple_list)
print(simple_list[0])
print(simple_list[3])
print(simple_list[-1])
print(simple_list[-2])
print(len(simple_list))
# Out:
# ['Dan', 2, 3, 4, 'python', 3.8]
# Dan
# 4
# 3.8
# python
# 6

# %%
# it is easy to change entries of list
simple_list[3] = 52
print(simple_list[3])
simple_list.append('to the back')
print(simple_list)
print(len(simple_list))
simple_list.pop(4)
print(simple_list)
# Out:
# 52
# ['Dan', 2, 3, 52, 'python', 3.8, 'to the back']
# 7
# ['Dan', 2, 3, 52, 3.8, 'to the back']

# %%
# it is easy to initialize a list of a particular size with all entries the same
repeated_list = [5]*4
print (repeated_list)
# Out:
# [5, 5, 5, 5]

# %%
# we can even use lists as entries of a list
simple_list[1] = [1,2,3]
print(simple_list)
print(simple_list[1])
print(simple_list[1][1])
# Out:
# ['Dan', [1, 2, 3], 3, 52, 3.8, 'to the back']
# [1, 2, 3]
# 2

# %%
# copying lists is a little tricky
list2 = simple_list
print(list2)
print(simple_list)

list2[1] = 0
print(list2)
print(simple_list)
# Out:
# ['Dan', [1, 2, 3], 3, 52, 3.8, 'to the back']
# ['Dan', [1, 2, 3], 3, 52, 3.8, 'to the back']
# ['Dan', 0, 3, 52, 3.8, 'to the back']
# ['Dan', 0, 3, 52, 3.8, 'to the back']

# %%
# we must use the copy method to prevent this behavior
list3 = simple_list.copy()
print(list3)
print(simple_list)

list3[0] = 'Mitchell'
print(list3)
print(simple_list)
# Out:
# ['Dan', 0, 3, 52, 3.8, 'to the back']
# ['Dan', 0, 3, 52, 3.8, 'to the back']
# ['Mitchell', 0, 3, 52, 3.8, 'to the back']
# ['Dan', 0, 3, 52, 3.8, 'to the back']

# %%
# tuple is an ordered collection of values that are unchangeable and allows duplicates
simple_tuple = (12, 42, 11, 99, 2351)
print(simple_tuple)
print(simple_tuple[1])
# Out:
# (12, 42, 11, 99, 2351)
# 42

# %%
# you can work around modifying tuple by casting it to a list
dummy = list(simple_tuple)
dummy[0] = 5
simple_tuple = tuple(dummy)
print(simple_tuple)
# Out:
# (5, 42, 11, 99, 2351)

# %%
# set is an unordered collection of values that are changeable and does not allow duplicates
simple_set = {11, -2, 'water', -2}
print(simple_set)
# Out:
# {'water', 11, -2}

# %%
print('water' in simple_set)
# Out:
# True

# %%
# you can't change values but you can add and remove entries from set
simple_set.add(72)
print(simple_set)
simple_set.remove('water')
print(simple_set)
# Out:
# {'water', 72, 11, -2}
# {72, 11, -2}

# %%
# a dictionary is a collection of values that are unordered (but indexed) and changeable
simple_dict = {
 "brand": "Apple",
 "product": "iPhone",
 "model": "X"
}
print (simple_dict)

print ('I bought an', simple_dict['product'], "model", simple_dict['model'], 'from', simple_dict['brand'])
# Out:
# {'brand': 'Apple', 'product': 'iPhone', 'model': 'X'}
# I bought an iPhone model X from Apple

# %%
simple_dict["model"] = "11 pro"
print ('I bought an', simple_dict['product'], "model", simple_dict ['model'], 'from', simple_dict ['brand'])
# Out:
# I bought an iPhone model 11 pro from Apple

# %%
# we can also add entries to the dictionary
simple_dict['color']='red'
print ('I bought a', simple_dict["color"], simple_dict['product'], "model", simple_dict['model'], 'from', simple_dict ['brand'])
# Out:
# I bought a red iPhone model 11 pro from Apple

# %% [markdown]
# ### Accessing data in lists
# A list is the main data type we will use for now and there are some rules we need to remember for accessing data in lists.
# Later we'll get into NumPy arrays, but the same rules here apply to them.
# With NumPy arrays we can access data in more ways.

# %%
simple_list = [1,5,2,7,3,66,1923,11]
# we can access multiple values in the list using the : sign
# we must be careful though
print (simple_list [2:5])

# why isn't 66 in the output?
# the number to the left of the is inclusive, but the number to the right is exclusive
print (simple_list [2:3])

# we can also use negative numbers
print (simple_list [-5:-1])
# Out:
# [2, 7, 3]
# [2]
# [7, 3, 66, 1923]

# %% [markdown]
# ![image.png](attachment:image.png)
