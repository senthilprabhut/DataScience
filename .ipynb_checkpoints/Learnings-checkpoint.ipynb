# %% [markdown]
# # 1. Loading libraries

# %%
# this will help in making the Python code more structured automatically (good coding practice)
# %load_ext nb_black

# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(color_codes=True)

import warnings
warnings.filterwarnings("ignore")

# Removes the limit from the number of displayed columns and rows.
# This is so I can see the entire dataframe when I print it
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
# from sklearn.linear_model import LinearRegression # to build linear regression_model
# from sklearn.model_selection import train_test_split # Sklearn package's randomized data splitting function
# from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error   # to check model performance

# %% [markdown]
# # 2. Loading and exploring the data

# %%
# index_col: Column(s) to use as the row labels of the ``DataFrame``,
# either given as string name or column index.
df = pd.read_csv("FIFA2019.csv", index_col=0)

print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
df.shape
# Out:
# There are 18207 rows and 88 columns
# (18207, 88)

# %%
# I'm now going to look at 10 random rows
# I'm setting the random seed via np.random.seed so that
# I get the same random results every time
#np.random.seed(1)
df.sample(n=10)
# Out:
#            ID             Name  Age  \
# 17900  243215       A. Daniels   19
# 15714  243664        F. Rieder   22
# 13821  237789        Y. Kimoto   24
# 7094   201845         M. Terki   26
# 15568   10884         M. Flynn   37
# 11575  235151       T. Ogihara   26
# 111    216460       J. Giménez   23
# 9942   239363        K. Dabila   21
# 3187   230389  Édundo Oliveira   26
# 17335  246063       E. Breivik   18
#
#                                                 Photo  Nationality  \
# 17900  https://cdn.sofifa.org/players/4/19/243215.png       Canada
# 15714  https://cdn.sofifa.org/players/4/19/243664.png      Austria
# 13821  https://cdn.sofifa.org/players/4/19/237789.png        Japan
# 7094   https://cdn.sofifa.org/players/4/19/201845.png      Algeria
# 15568   https://cdn.sofifa.org/players/4/19/10884.png        Wales
# 11575  https://cdn.sofifa.org/players/4/19/235151.png        Japan
# 111    https://cdn.sofifa.org/players/4/19/216460.png      Uruguay
# 9942   https://cdn.sofifa.org/players/4/19/239363.png  Ivory Coast
# 3187   https://cdn.sofifa.org/players/4/19/230389.png       Brazil
# 17335  https://cdn.sofifa.org/players/4/19/246063.png       Norway
#
#                                        Flag  Overall  Potential  \
# 17900   https://cdn.sofifa.org/flags/70.png       51         63
# 15714    https://cdn.sofifa.org/flags/4.png       59         66
# 13821  https://cdn.sofifa.org/flags/163.png       62         67
# 7094    https://cdn.sofifa.org/flags/97.png       68         71
# 15568   https://cdn.sofifa.org/flags/50.png       59         59
# 11575  https://cdn.sofifa.org/flags/163.png       64         67
# 111     https://cdn.sofifa.org/flags/60.png       84         88
# 9942   https://cdn.sofifa.org/flags/108.png       65         75
# 3187    https://cdn.sofifa.org/flags/54.png       73         73
# 17335   https://cdn.sofifa.org/flags/36.png       54         68
#
#                       Club                                        Club Logo  \
# 17900           Toronto FC  https://cdn.sofifa.org/teams/2/light/111651.png
# 15714  FC Wacker Innsbruck    https://cdn.sofifa.org/teams/2/light/2045.png
# 13821         Cerezo Osaka  https://cdn.sofifa.org/teams/2/light/101148.png
# 7094      Sporting Lokeren    https://cdn.sofifa.org/teams/2/light/2007.png
# 15568       Newport County  https://cdn.sofifa.org/teams/2/light/112254.png
# 11575  Yokohama F. Marinos  https://cdn.sofifa.org/teams/2/light/101151.png
# 111        Atlético Madrid     https://cdn.sofifa.org/teams/2/light/240.png
# 9942            LOSC Lille      https://cdn.sofifa.org/teams/2/light/65.png
# 3187              Cruzeiro     https://cdn.sofifa.org/teams/2/light/568.png
0
#
#        StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 17900            40.0           44.0       8.0        14.0       14.0
# 15714            52.0           32.0      12.0        10.0       11.0
# 13821            65.0           61.0      11.0         7.0        9.0
# 7094             63.0           57.0       7.0        13.0        8.0
# 15568            46.0           45.0       9.0        13.0       12.0
# 11575            66.0           59.0      14.0        14.0        8.0
# 111              86.0           87.0       9.0        11.0        7.0
# 9942             67.0           69.0      12.0         7.0       15.0
# 3187             77.0           72.0       7.0        13.0        7.0
# 17335            59.0           58.0      14.0         8.0       14.0
#
#        GKPositioning  GKReflexes Release Clause
# 17900           13.0         7.0          €102K
# 15714           12.0        14.0          €363K
# 13821           13.0        10.0          €464K
# 7094             9.0         7.0          €1.5M
# 15568            7.0        10.0           €88K
# 11575            8.0        11.0          €629K
# 111             10.0        15.0         €72.3M
# 9942            15.0         7.0          €1.7M
# 3187             8.0        15.0          €6.6M
# 17335           11.0        11.0          €244K

# %%
# Drop the columns that are not useful
df.drop(['ID', 'Photo', 'Flag', 'Club Logo', 'Real Face', 'Jersey Number'],axis=1,inplace=True)

# %% [markdown]
# ## Dealing with Missing Values

# %%
# Get the data type and null value count for each of the columns
# If a data type for numerical column is "object", then that column is missing some value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18207 entries, 0 to 18206
# Data columns (total 82 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      18207 non-null  object
#  1   Age                       18207 non-null  int64
#  2   Nationality               18207 non-null  object
#  3   Overall                   18207 non-null  int64
#  4   Potential                 18207 non-null  int64
#  5   Club                      17966 non-null  object
#  6   Value                     18207 non-null  object
#  7   Wage                      18207 non-null  object
#  8   Special                   18207 non-null  int64
#  9   Preferred Foot            18159 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Weak Foot                 18159 non-null  float64
#  12  Skill Moves               18159 non-null  float64
#  13  Work Rate                 18159 non-null  object
#  14  Body Type                 18159 non-null  object
#  15  Position                  18147 non-null  object
#  16  Joined                    16654 non-null  object
#  17  Loaned From               1264 non-null   object
#  18  Contract Valid Until      17918 non-null  object
#  19  Height                    18159 non-null  object
#  20  Weight                    18159 non-null  object
#  21  LS                        16122 non-null  object
#  22  ST                        16122 non-null  object
#  23  RS                        16122 non-null  object
#  24  LW                        16122 non-null  object
#  25  LF                        16122 non-null  object
#  26  CF                        16122 non-null  object
#  27  RF                        16122 non-null  object
#  28  RW                        16122 non-null  object
#  29  LAM                       16122 non-null  object
#  30  CAM                       16122 non-null  object
#  31  RAM                       16122 non-null  object
#  32  LM                        16122 non-null  object
#  33  LCM                       16122 non-null  object
#  34  CM                        16122 non-null  object
#  35  RCM                       16122 non-null  object
#  36  RM                        16122 non-null  object
#  37  LWB                       16122 non-null  object
#  38  LDM                       16122 non-null  object
#  39  CDM                       16122 non-null  object
#  40  RDM                       16122 non-null  object
#  41  RWB                       16122 non-null  object
#  42  LB                        16122 non-null  object
#  43  LCB                       16122 non-null  object
#  44  CB                        16122 non-null  object
#  45  RCB                       16122 non-null  object
#  46  RB                        16122 non-null  object
#  47  Crossing                  18159 non-null  float64
#  48  Finishing                 18159 non-null  float64
#  49  HeadingAccuracy           18159 non-null  float64
#  50  ShortPassing              18159 non-null  float64
#  51  Volleys                   18159 non-null  float64
#  52  Dribbling                 18159 non-null  float64
#  53  Curve                     18159 non-null  float64
#  54  FKAccuracy                18159 non-null  float64
#  55  LongPassing               18159 non-null  float64
#  56  BallControl               18159 non-null  float64
#  57  Acceleration              18159 non-null  float64
#  58  SprintSpeed               18159 non-null  float64
#  59  Agility                   18159 non-null  float64
#  60  Reactions                 18159 non-null  float64
#  61  Balance                   18159 non-null  float64
#  62  ShotPower                 18159 non-null  float64
#  63  Jumping                   18159 non-null  float64
#  64  Stamina                   18159 non-null  float64
#  65  Strength                  18159 non-null  float64
#  66  LongShots                 18159 non-null  float64
#  67  Aggression                18159 non-null  float64
#  68  Interceptions             18159 non-null  float64
#  69  Positioning               18159 non-null  float64
#  70  Vision                    18159 non-null  float64
#  71  Penalties                 18159 non-null  float64
#  72  Composure                 18159 non-null  float64
#  73  Marking                   18159 non-null  float64
#  74  StandingTackle            18159 non-null  float64
#  75  SlidingTackle             18159 non-null  float64
#  76  GKDiving                  18159 non-null  float64
#  77  GKHandling                18159 non-null  float64
#  78  GKKicking                 18159 non-null  float64
#  79  GKPositioning             18159 non-null  float64
#  80  GKReflexes                18159 non-null  float64
#  81  Release Clause            16643 non-null  object
# dtypes: float64(37), int64(4), object(41)
# memory usage: 11.5+ MB

# %%
# looking at which columns have the most missing values
df.isnull().sum().sort_values(ascending=False)
# Out:
# Loaned From                 16943
# RWB                          2085
# LCM                          2085
# LF                           2085
# LW                           2085
# RS                           2085
# ST                           2085
# LS                           2085
# RW                           2085
# LAM                          2085
# CAM                          2085
# RAM                          2085
# LM                           2085
# CM                           2085
# RF                           2085
# RCM                          2085
# RM                           2085
# LWB                          2085
# LDM                          2085
# CDM                          2085
# RDM                          2085
# LB                           2085
# LCB                          2085
# CB                           2085
# RCB                          2085
# RB                           2085
# CF                           2085
# Release Clause               1564
# Joined                       1553
# Contract Valid Until          289
# Club                          241
# Position                       60
# Weight                         48
# Positioning                    48
# Agility                        48
# Reactions                      48
# Balance                        48
# ShotPower                      48
# Jumping                        48
# Stamina                        48
# Strength                       48
# LongShots                      48
# Aggression                     48
# Interceptions                  48
# Penalties                      48
# Vision                         48
# Acceleration                   48
# Composure                      48
# Marking                        48
# StandingTackle                 48
# SlidingTackle                  48
# GKDiving                       48
# GKHandling                     48
# GKKicking                      48
# GKPositioning                  48
# GKReflexes                     48
# SprintSpeed                    48
# LongPassing                    48
# BallControl                    48
# Preferred Foot                 48
# FKAccuracy                     48
# Curve                          48
# Dribbling                      48
# Volleys                        48
# ShortPassing                   48
# HeadingAccuracy                48
# Finishing                      48
# Crossing                       48
# Body Type                      48
# Work Rate                      48
# Height                         48
# Skill Moves                    48
# Weak Foot                      48
# International Reputation       48
# Potential                       0
# Special                         0
# Wage                            0
# Age                             0
# Value                           0
# Overall                         0
# Nationality                     0
# Name                            0
# dtype: int64

# %%
# data = pd.DataFrame(
#     {
#         "Col1": [100, 200, 300, 400],
#         "Col2": [500, 600, 700, 800],
#         "Col3": [900, 1000, 1100, 1200],
#         "Col4": ["Nature", "Wildlife", "Animals", "Humans"],
#     }
# )
# data
# np.mean(data, axis=1)
# data["Col4"].str.replace("Nature", "Beauty")
# data["Col4"].str.replace("Nature","Beauty", axis=0,inplace=False)
# data["Col4"].replace("Nature", "Beauty", inplace=False)
p1 = pd.Series([2, 5, 12, 15, 19, 4, 6, 11, 16, 18, 12, 12, 42], name="legs")
sns.boxplot(x=p1)
# Out:
# <AxesSubplot:xlabel='legs'>

# %%
## Pearson Coefficient
from scipy.stats import pearsonr
list1 = [4, 5, 8, 10, 11]
list2 = [50, 48, 45 , 42, 41]

corr, pvalue= pearsonr(list1,list2)
print(corr)
print (pvalue)
# Out:
# -0.9963817945771083
# 0.0002611186203867432
